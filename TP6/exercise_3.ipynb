# %% [markdown]
# <a href="https://colab.research.google.com/github/JasLieb/IML/blob/master/TP6/exercise_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise 13: Differents linkage, differentes classifications!

# %% [markdown]
# From the course _Transition to Data Science_. [Buy the entire course for just $10](https://www.udemy.com/transition-to-data-science-in-python/?couponCode=HIERARCH-NBS) for many more exercises and helpful video lectures.

# %% [markdown]
# **Etape 1:** Chargement des données

# %%
import pandas as pd

scores_df = pd.read_csv('eurovision-2016-televoting.csv', index_col=0)
country_names = list(scores_df.index)
scores_df
# Out:
#                       Armenia  Australia  ...  Ukraine  United Kingdom
# From country                              ...
# Albania                   2.0       12.0  ...      6.0             0.0
# Armenia                   NaN        0.0  ...     10.0             0.0
# Australia                 0.0        NaN  ...      8.0             4.0
# Austria                   0.0        3.0  ...     10.0             0.0
# Azerbaijan                0.0        2.0  ...     10.0             0.0
# Belarus                   7.0        1.0  ...     10.0             0.0
# Belgium                   7.0        4.0  ...      2.0             0.0
# Bosnia & Herzegovina      0.0        3.0  ...      7.0             0.0
# Bulgaria                  8.0        5.0  ...     10.0             0.0
# Croatia                   0.0        5.0  ...     10.0             0.0
# Cyprus                    8.0        5.0  ...      7.0             0.0
# Czech Republic            8.0        1.0  ...     12.0             0.0
# ...

# %% [markdown]
# **Etape 2:**
#
#
#
# Affichez le DataFrame et Analyser. Chaque ligne représente un pays qui a voté.
#
# Remarquez les valeurs NaN ("not-a-number"). Ceux-ci correspondent aux scores manquants dans le fichier CSV d'origine. Ces scores sont manquants car les pays ayant voté pour eux mêmes alors qu'ils n'ont pas été autorisés à le faire.

# %%
scores_df
# Out:
#                       Armenia  Australia  ...  Ukraine  United Kingdom
# From country                              ...
# Albania                   2.0       12.0  ...      6.0             0.0
# Armenia                   NaN        0.0  ...     10.0             0.0
# Australia                 0.0        NaN  ...      8.0             4.0
# Austria                   0.0        3.0  ...     10.0             0.0
# Azerbaijan                0.0        2.0  ...     10.0             0.0
# Belarus                   7.0        1.0  ...     10.0             0.0
# Belgium                   7.0        4.0  ...      2.0             0.0
# Bosnia & Herzegovina      0.0        3.0  ...      7.0             0.0
# Bulgaria                  8.0        5.0  ...     10.0             0.0
# Croatia                   0.0        5.0  ...     10.0             0.0
# Cyprus                    8.0        5.0  ...      7.0             0.0
# Czech Republic            8.0        1.0  ...     12.0             0.0
# ...

# %% [markdown]
# **Step 3:** Remplacer les NaN avec le score le plus élevé possible (12) - nous supposons que les pays voteraient pour eux-mêmes, s'ils y étaient autorisés.

# %%
df_no_na= scores_df.fillna(12)

# %% [markdown]
# **Step 4:** Importer les fonctions  `normalize` from `sklearn.preprocessing`.

# %%
 from sklearn.preprocessing import Normalizer

# %% [markdown]
# **Etape 5:**
#
#
# Appliquez la fonction de normalisation à `scores_df.values` en affectant le résultat à `samples`.
#
# (Pourquoi devons-nous normaliser? Parce que maintenant que les valeurs manquantes sont remplies avec la valeur de de 12 (points), on risque de dépasser les intervalles initialement définis.

# %%
transformer = Normalizer().fit(df_no_na)
transformer
X = transformer.transform(df_no_na)

# %% [markdown]
# **Step 6:** Import des classes necessaires:
#  + `linkage` and `dendrogram` from `scipy.cluster.hierarchy`.
#  + `matplotlib.pyplot` as `plt`.

# %%
from scipy.cluster.hierarchy import dendrogram, linkage
from matplotlib import pyplot as plt

# %% [markdown]
# **Etape 7:** Effectuez un clustering hiérarchique sur `samples` en utilisant la fonction` linkage () `avec l'argument` method = 'single'`.

# %%
Z = linkage(X, 'single')
fig = plt.figure(figsize=(25, 10))
dn = dendrogram(Z)
plt.show()

# %% [markdown]
# **Step 8:** Plot a dendrogram of the hierarchical clustering, using the list `country_names` as the `labels`. In addition, specify the `leaf_rotation=90`, and `leaf_font_size=6` keyword arguments as you have done earlier.
#
#
# Tracez un dendrogramme du clustering hiérarchique, en utilisant `country_names` comme `labels`.
# De plus, spécifiez les arguments  `leaf_rotation=90`, et `leaf_font_size=6`.

# %%
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import linkage, dendrogram

# Calculate the linkage: mergings
mergings = linkage(X, method='single')

# Plot the dendrogram
dendrogram(mergings, labels=country_names, leaf_rotation=90, leaf_font_size=6)
plt.show()
